# %%
import numpy as np
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

# Generate a dataset and plot it
np.random.seed(0)
X, y = make_moons(200, noise=0.20)
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.Spectral)

def softmax(z):
    numerator = np.exp(z - np.max(z))
    denominator = np.sum(numerator)
    return numerator/denominator

def convert2D(arr):
    y2d = np.zeros((len(arr), 2))
    for c in range(len(arr)):
        if arr[c] == 0:
            y2d[c][0] = 1
        else:
            y2d[c][1] = 1
    
    return y2d

def calculate_loss(model, X, y):
    yNew = convert2D(y)

    predicted = []
    for i in range(len(X)):
        predicted.append(predict2(model, X[i]))

    yHat = np.array(predicted)
    loss = (1/len(X)) * (-np.sum(yNew * np.log(yHat)))

    return loss

def predict(model, x):
    alpha = np.matmul(x, model['W1']) + model['b1']
    h = np.tanh(alpha)
    zeta = np.matmul(h, model['W2']) + model['b2']
    yhat = softmax(zeta)
    
    return np.argmax(yhat, axis=1)

def predict2(model, x):
    alpha = np.matmul(x, model['W1']) + model['b1']
    h = np.tanh(alpha)
    zeta = np.matmul(h, model['W2']) + model['b2']
    yhat = softmax(zeta)
    
    return yhat

def build_model(X, y, nn_hdim, num_passes=20000, print_loss=True):
    W1 = np.random.rand(2, nn_hdim)
    W2 = np.random.rand(nn_hdim, 2)
    b1 = np.random.rand(nn_hdim)
    b2 = np.random.rand(2)

    model = {'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2}

    yNew = convert2D(y)

    for i in range(num_passes):
        yHat = predict2(model, X)

        alpha = np.matmul(X, model['W1']) + model['b1']
        h = np.tanh(alpha)

        L_yHat = np.subtract(yHat, yNew)
        L_a = np.multiply( ( 1 - pow(np.tanh(alpha), 2) ) , ( np.matmul(L_yHat, W2.T) ) )

        partW2 = np.matmul(np.transpose(h), L_yHat)
        partb2 = np.sum(L_yHat)
        partW1 = np.matmul(np.transpose(X), L_a)
        partb1 = np.sum(L_a)

        W1 = np.subtract(W1, np.multiply(0.01, partW1))
        W2 = np.subtract(W2, np.multiply(0.01, partW2))
        b1 = np.subtract(b1, np.multiply(0.01, partb1))
        b2 = np.subtract(b2, np.multiply(0.01, partb2))

        model['W1'] = W1
        model['W2'] = W2
        model['b1'] = b1
        model['b2'] = b2

        if print_loss == True:
            if ( ((i % 1000) == 0) & (i != 0) ):
                print("Loss after", i, "iterations:", calculate_loss(model, X, y))
            if (i == (num_passes - 1)):
                print("Loss after", i+1, "iterations:", calculate_loss(model, X, y))

    return model

def plot_decision_boundary(pred_func, X, y):
        # Set min and max values and give it some padding
        x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
        y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
        h = 0.01
        # Generate a grid of points with distance h between them
        xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
        # Predict the function value for the whole gid
        Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
        Z = Z.reshape(xx.shape)
        # Plot the contour and training examples
        plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
        plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)

plt.figure(figsize=(16, 32))
hidden_layer_dimensions = [1, 2, 3, 4]
for i, nn_hdim in enumerate(hidden_layer_dimensions):
    plt.subplot(5, 2, i+1)
    plt.title('HiddenLayerSize%d' % nn_hdim)
    model = build_model(X, y, nn_hdim)
    plot_decision_boundary(lambda x: predict(model, x), X, y)
plt.show()
# Out:
# Loss after 1000 iterations: 0.6931494939394128
# Loss after 2000 iterations: 0.6931471810726331
# Loss after 3000 iterations: 0.6931471807373868
# Loss after 4000 iterations: 0.6931471806599305
# Loss after 5000 iterations: 0.6931471806240443
# Loss after 6000 iterations: 0.693147180604432
# Loss after 7000 iterations: 0.6931471805927527
# Loss after 8000 iterations: 0.6931471805850484
# Loss after 9000 iterations: 0.6931471805797003
# Loss after 10000 iterations: 0.6931471805758892
# Loss after 11000 iterations: 0.6931471805732605
# Loss after 12000 iterations: 0.6931471805712596
# Loss after 13000 iterations: 0.6931471805692223
# Loss after 14000 iterations: 0.6931471805682583
# Loss after 15000 iterations: 0.6931471805671486
# Loss after 16000 iterations: 0.6931471805664393
# Loss after 17000 iterations: 0.6931471805654388
# Loss after 18000 iterations: 0.6931471805646748
# Loss after 19000 iterations: 0.693147180564329
# Loss after 19999 iterations: 0.6931471805640016
# Loss after 1000 iterations: 0.6931471797141698
# Loss after 2000 iterations: 0.6931471804029997
# Loss after 3000 iterations: 0.6931471805037259
# Loss after 4000 iterations: 0.6931471805328546
# Loss after 5000 iterations: 0.6931471805445761
# Loss after 6000 iterations: 0.6931471805502872
# Loss after 7000 iterations: 0.693147180553388
# Loss after 8000 iterations: 0.6931471805552889
# Loss after 9000 iterations: 0.6931471805563257
# Loss after 10000 iterations: 0.6931471805574535
# Loss after 11000 iterations: 0.6931471805579628
# Loss after 12000 iterations: 0.6931471805583812
# Loss after 13000 iterations: 0.6931471805586356
# Loss after 14000 iterations: 0.6931471805588538
# Loss after 15000 iterations: 0.6931471805587447
# Loss after 16000 iterations: 0.6931471805592904
# Loss after 17000 iterations: 0.6931471805596905
# Loss after 18000 iterations: 0.6931471805595814
# Loss after 19000 iterations: 0.6931471805597269
# Loss after 19999 iterations: 0.6931471805593631
# Loss after 1000 iterations: 0.69314718148744
# Loss after 2000 iterations: 0.6931471808048117
# Loss after 3000 iterations: 0.6931471806717693
# Loss after 4000 iterations: 0.6931471806240106
# Loss after 5000 iterations: 0.6931471806013548
# Loss after 6000 iterations: 0.6931471805891039
# Loss after 7000 iterations: 0.6931471805816096
# Loss after 8000 iterations: 0.6931471805766256
# Loss after 9000 iterations: 0.6931471805733693
# Loss after 10000 iterations: 0.6931471805708591
# Loss after 11000 iterations: 0.6931471805687491
# Loss after 12000 iterations: 0.6931471805674576
# Loss after 13000 iterations: 0.6931471805665299
# Loss after 14000 iterations: 0.693147180565766
# Loss after 15000 iterations: 0.6931471805647473
# Loss after 16000 iterations: 0.6931471805644199
# Loss after 17000 iterations: 0.6931471805640197
# Loss after 18000 iterations: 0.693147180563474
# Loss after 19000 iterations: 0.6931471805628192
# Loss after 19999 iterations: 0.6931471805632922
# Loss after 1000 iterations: 0.6931471769502351
# Loss after 2000 iterations: 0.6931471797820139
# Loss after 3000 iterations: 0.6931471802406581
# Loss after 4000 iterations: 0.6931471803895058
# Loss after 5000 iterations: 0.6931471804552806
# Loss after 6000 iterations: 0.6931471804893866
# Loss after 7000 iterations: 0.6931471805093955
# Loss after 8000 iterations: 0.693147180522274
# Loss after 9000 iterations: 0.693147180530423
# Loss after 10000 iterations: 0.6931471805364984
# Loss after 11000 iterations: 0.6931471805410278
# Loss after 12000 iterations: 0.6931471805440472
# Loss after 13000 iterations: 0.6931471805471031
# Loss after 14000 iterations: 0.6931471805486674
# Loss after 15000 iterations: 0.6931471805503046
# Loss after 16000 iterations: 0.6931471805514687
# Loss after 17000 iterations: 0.6931471805526692
# Loss after 18000 iterations: 0.6931471805531422
# Loss after 19000 iterations: 0.6931471805542699
# Loss after 19999 iterations: 0.6931471805544155
